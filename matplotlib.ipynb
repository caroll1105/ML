# %%
import matplotlib.pyplot as plt

# %%
plt.plot([4,3,2,1],[1,2,3,4])
plt.plot([1,2,3,4],[1,2,3,4])
plt.show()

# %%
plt.plot([4,4,4,4],[1,2,3,4])
plt.plot([1,2,3,4],[4,4,4,4])
plt.plot([1,1,1,1],[1,2,3,4])
plt.plot([1,2,3,4],[1,1,1,1])
plt.show()

# %%
plt.plot([4,4,4,4],[1,2,3,4])
plt.plot([1,2,3,4],[4,4,4,4])
plt.plot([1,1,1,1],[1,2,3,4])
plt.plot([1,2,3,4],[1,1,1,1])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Demo-Line Chart')
plt.plot([4,4,4,4],[1,2,3,4])
plt.plot([1,2,3,4],[4,4,4,4])
plt.plot([1,1,1,1],[1,2,3,4])
plt.plot([1,2,3,4],[1,1,1,1])
plt.show()

# %%
plt.plot([1,2,3,4],[14,8,4,5], 'b--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Demo-Line Chart')
plt.show()

# %%
plt.plot([1,2,3,4],[14,8,4,5], 'r--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Demo-Line Chart')
plt.show()

# %%
plt.plot([1,2,3,4],[14,8,4,5], 'y--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Demo-Line Chart')
plt.show()

# %%
plt.plot([1,2,3,4],[14,8,4,5], 'p--', marker='+')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Demo-Line Chart')
plt.show()

# %%
plt.plot([1,2,3,4],[14,8,4,5], 'p--', marker='.')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Demo-Line Chart')
plt.show()

# %%
plt.plot([1,2,3,4],[14,8,4,5], 'p--', marker='2')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Demo-Line Chart')
plt.show()

# %%
plt.plot([1,2,3,4],[14,8,4,5], 'p--', marker='+', mec='r', lw=5)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Demo-Line Chart')
plt.show()

# %%
plt.plot([1,2,3,4],[14,8,4,5], 'p--', marker='+', mec='r', lw=5, zorder=3)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Demo-Line Chart')
plt.show()

# %%
x=[1,2,3,4]
y=[14,20,25,50]
plt.plot(x,y,'g--', marker='+', mec='r', lw=5, zorder=3)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Demo-Line Chart')
plt.show()

# %%
x=[10,40,60,80,90,52,100,25,52,45,56,65,12,15,17,18,25,35,15,15,15]
y=[10,20,30,40,60]
plt.hist(x,bins=y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Demo-Histogram')
plt.show()

# %%
x=[10,20,30,40,50]
plt.pie(x,explode=[0,0.1,0,0,0],shadow=True)
plt.show()

# %%
x=[10,20,30,40,50]
plt.pie(x,explode=[0,0,0,0,0.1],shadow=True)
plt.show()
